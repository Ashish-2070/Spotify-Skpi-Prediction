# %% [markdown]
# #### Loading Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Importing Track Feature Data

# %%
Track = pd.read_csv('tf_000000000000.csv')

# %%
Track.head(2)
# Out:
#                                  track_id    duration  release_year  \
# 0  t_2e8f4b71-8a0b-4b9c-b7d8-fb5208e87f9f  326.013336          1971
# 1  t_dae2ec0e-ec7b-4b3e-b60c-4a884d0eccb0  147.813324          1963
#
#    us_popularity_estimate  acousticness  beat_strength  bounciness  \
# 0               99.582885      0.716209       0.366495    0.332605
# 1               97.272035      0.839460       0.362212    0.389829
#
#    danceability  dyn_range_mean    energy  flatness  instrumentalness  key  \
# 0      0.439835        5.805774  0.238847  1.010700      6.533861e-01    0
# 1      0.507580        6.845427  0.420476  1.000398      3.941550e-09    0
#
#    liveness  loudness  mechanism   mode  organism  speechiness       tempo  \
# 0  0.769258   -17.094   0.199170  major  0.759699     0.033940  100.370003
# 1  0.085844   -11.295   0.357639  major  0.747436     0.049856  141.334000
#
#    time_signature   valence  acoustic_vector_0  acoustic_vector_1  \
# 0               4  0.223395           0.146012          -0.706908
# 1               4  0.484702           0.039554          -0.539554
#
#    acoustic_vector_2  acoustic_vector_3  acoustic_vector_4  acoustic_vector_5  \
# 0           0.259496           0.481157           0.238427          -0.098389
# 1           0.105141           0.692589           0.226047          -0.468162
#
#    acoustic_vector_6  acoustic_vector_7
# 0          -0.254960          -0.227383
# 1           0.164389          -0.769024

# %%
Track.dtypes
# Out:
# track_id                   object
# duration                  float64
# release_year                int64
# us_popularity_estimate    float64
# acousticness              float64
# beat_strength             float64
# bounciness                float64
# danceability              float64
# dyn_range_mean            float64
# energy                    float64
# flatness                  float64
# instrumentalness          float64
# key                         int64
# liveness                  float64
# loudness                  float64
# mechanism                 float64
# mode                       object
# organism                  float64
# speechiness               float64
# tempo                     float64
# time_signature              int64
# valence                   float64
# acoustic_vector_0         float64
# acoustic_vector_1         float64
# acoustic_vector_2         float64
# acoustic_vector_3         float64
# acoustic_vector_4         float64
# acoustic_vector_5         float64
# acoustic_vector_6         float64
# acoustic_vector_7         float64
# dtype: object

# %%
Track.describe()
# Out:
#            duration  release_year  us_popularity_estimate  acousticness  \
# count  1.853311e+06  1.853311e+06            1.853311e+06  1.853311e+06
# mean   2.332751e+02  2.009259e+03            9.557489e+01  3.469483e-01
# std    1.086198e+02  1.103782e+01            2.735883e+00  3.426890e-01
# min    3.000095e+01  1.950000e+03            9.000000e+01  0.000000e+00
# 25%    1.768273e+02  2.006000e+03            9.338338e+01  2.661495e-02
# 50%    2.178956e+02  2.013000e+03            9.575712e+01  2.202808e-01
# 75%    2.671304e+02  2.017000e+03            9.792292e+01  6.529128e-01
# max    1.799815e+03  2.018000e+03            1.000000e+02  9.957964e-01
#
#        beat_strength    bounciness  danceability  dyn_range_mean  \
# count   1.853311e+06  1.853311e+06  1.853311e+06    1.853311e+06
# mean    4.617319e-01  4.791076e-01  5.564984e-01    7.848231e+00
# std     1.717286e-01  1.989990e-01  1.858682e-01    2.679272e+00
# min     0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25
# %%
Track.describe(include=['O'])
# Out:
#                                       track_id     mode
# count                                  1853311  1853311
# unique                                 1853311        2
# top     t_54bfbe8b-0ef5-4655-abbe-1e67c8ebbe1e    major
# freq                                         1  1206482

# %%
Track.isnull().sum()
# Out:
# track_id                  0
# duration                  0
# release_year              0
# us_popularity_estimate    0
# acousticness              0
# beat_strength             0
# bounciness                0
# danceability              0
# dyn_range_mean            0
# energy                    0
# flatness                  0
# instrumentalness          0
# key                       0
# liveness                  0
# loudness                  0
# mechanism                 0
# mode                      0
# organism                  0
# speechiness               0
# tempo                     0
# time_signature            0
# valence                   0
# acoustic_vector_0         0
# acoustic_vector_1         0
# acoustic_vector_2         0
# acoustic_vector_3         0
# acoustic_vector_4         0
# acoustic_vector_5         0
# acoustic_vector_6         0
# acoustic_vector_7         0
# dtype: int64

# %% [markdown]
# ##### Release Year

# %%
plt.figure(figsize=(18,6))
Track['release_year'].hist(bins=50)
plt.show()

# %%
Track['release_year'].value_counts().head(20)
# Out:
# 2018    247729
# 2017    236592
# 2016    171664
# 2015    137520
# 2014    114432
# 2013     95912
# 2012     84740
# 2011     74269
# 2010     64660
# 2009     56793
# 2008     50193
# 2007     45098
# 2006     43540
# 2005     38769
# 2004     31340
# 2003     29351
# 2002     26004
# 2001     24196
# 2000     23056
# 1999     21397
# Name: release_year, dtype: int64

# %% [markdown]
# ##### Duration

# %%
plt.figure(figsize=(18,6))
Track['duration'].hist(bins=50)
plt.show()

# %% [markdown]
# #### US Poularity Estimate

# %%
plt.figure(figsize=(18,6))
Track['us_popularity_estimate'].hist(bins=50)
plt.show()

# %% [markdown]
# #### Acousticness

# %%
col = ['duration','release_year','us_popularity_estimate',
       'acousticness','beat_strength','bounciness',
       'danceability','dyn_range_mean','energy',
       'flatness','instrumentalness','key','liveness',
       'loudness','mechanism','mode','organism',
       'speechiness','tempo','time_signature',
       'valence','acoustic_vector_0','acoustic_vector_1',
       'acoustic_vector_2','acoustic_vector_3','acoustic_vector_4',
       'acoustic_vector_5','acoustic_vector_6','acoustic_vector_7']

# %%
len(col)
# Out:
# 29

# %%
plt.figure(figsize=(30,20))
n = 1

for i in range(3,len(col)):
    plt.subplot(6,6,n)
    Track[col[i]].hist()
    plt.xlabel(col[i])
    n +=1

# %% [markdown]
# #### acoustic_vector 0-8

# %%
plt.figure(figsize=(20,30))
n = 1

for colname in ['acoustic_vector_0','acoustic_vector_1','acoustic_vector_2',
                'acoustic_vector_3','acoustic_vector_4','acoustic_vector_5',
                'acoustic_vector_6','acoustic_vector_7']:
    plt.subplot(6,3,n)
    Track[colname].hist()
    plt.xlabel(colname)
    n +=1

# %% [markdown]
# #### Mode

# %%
Track['mode'].unique()
# Out:
# array(['major', 'minor'], dtype=object)

# %%
Track['mode'].value_counts()
# Out:
# major    1206482
# minor     646829
# Name: mode, dtype: int64

# %%
Track['mode'] = Track['mode'].replace({
    'major': 1,
    'minor': 0
})

# %% [markdown]
# #### Correlation

# %%
corrmat=Track.corr()
f, ax = plt.subplots(figsize=(30, 20))
sns.heatmap(corrmat,cbar=True, annot=True, vmax=.8, square=True, fmt='.2f', annot_kws={'size': 10});

# %%
Track.to_csv('Track.csv')
